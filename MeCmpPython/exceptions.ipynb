# %%
age= 19
if(age>18) # cause syntax error
    print('You are eligible to vote.')
# Out:
#   Cell In[3], line 2
#     if(age>18) # cause syntax error
#                ^
# SyntaxError: expected ':'

# %%
# Solution: 
age= 19
if(age>18):
    print('You are eligible to vote.')
# Out:
# You are eligible to vote.

# %%
age=20
if(age>18):
print('You are eligible to vote.')
# Out:
#   Cell In[4], line 3
#     print('You are eligible to vote.')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# SOlution:
age=20
if(age>18):
    print('You are eligible to vote.')
# Out:
# You are eligible to vote.

# %%
ages =[58,88,48,65,15]
for age in ages:
if age>18:
print(f"Man/Woman with {age} can vote.”)
# Out:
#   Cell In[7], line 4
#     print(f"Man/Woman with {age} can vote.”)
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
ages =[58,88,48,65,15]
for age in ages:
    if age>18:
        print(f'Man/Woman with {age} can vote')
# Out:
# Man/Woman with 58 can vote
# Man/Woman with 88 can vote
# Man/Woman with 48 can vote
# Man/Woman with 65 can vote

# %%
numbers = [10, 20, 30, 40, 50]
total = 0
for number in numbers:
   total += number
# Calculate the average (this has a logical error)
average = total/len(numbers)-1
print("The average is:", average)
# Out:
# The average is: 29.0

# %%
numbers = [10, 20, 30, 40, 50]
total = 0
for number in numbers:
   total += number
# Calculate the average (this has a logical error)
average = total/len(numbers)
print("The average is:", average)
# Out:
# The average is: 30.0

# %%
x = 10
y = 0
print(x / y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 x = 10
#       2 y = 0
# ----> 3 print(x / y)
#
# ZeroDivisionError: division by zero

# %%
try:
    x = 10
    y = 0
    print(x / y)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %%
try:
    lst = [1, 2, 3]
    print(lst[5])  # This will cause an IndexError
except IndexError:
    print("Error: Index out of range.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Index out of range.

# %%
try:
    x = 10
    y = 2
    print(x / y)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
finally:
    print("Execution completed.")
# Out:
# 5.0
# Execution completed.

# %%
try:
    pass
    #python statements
except Exception as e:
    raise Exception(f"This is a custom exception. Error: {e}")

# %%
try:
    with open("data.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("Error: The file was not found. Please check the file path.")
except PermissionError:
    print("Error: You do not have the required permission to read the file.")
# Out:
# Error: The file was not found. Please check the file path.
